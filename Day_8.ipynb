# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder

# %%
data_dir ='/content/drive/MyDrive/PlantDisease/Data'
categories = os.listdir(data_dir)

# %%
data_dir ='/content/drive/MyDrive/PlantDisease/Data'
categories = os.listdir(data_dir)

images = []
labels = []

for category in categories:
  print(category)
  folder_path = os.path.join(data_dir, category)
  for img_file in os.listdir(folder_path):
    img_path = os.path.join(folder_path, img_file)
    img = cv2.imread(img_path)
    if img is not None:
      img = cv2.resize(img, (64, 64))
      images.append(img)
      labels.append(category)
images = np.array(images)
# Out:
# Tomato___Late_blight
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Tomato_mosaic_virus
# Tomato___Target_Spot
# Tomato___healthy
# Tomato___Early_blight
# Tomato___Bacterial_spot

# %%
x = np.array(images)
y = np.array(labels)  # Corrected typo here

print("Labels: ",np.unique(y))
print("Data Shape: ",x.shape)
# Out:
# Labels:  ['Tomato___Bacterial_spot' 'Tomato___Early_blight' 'Tomato___Late_blight'
#  'Tomato___Target_Spot' 'Tomato___Tomato_Yellow_Leaf_Curl_Virus'
#  'Tomato___Tomato_mosaic_virus' 'Tomato___healthy']
# Data Shape:  (12987, 64, 64, 3)

# %%
class_counts =pd.Series(y).value_counts()
print("Class Distribution")
print(class_counts)

#plot class distribution
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x = class_counts.index, y= class_counts.values)
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Class Distribution")
plt.show()
# Out:
# Class Distribution
# Tomato___Tomato_Yellow_Leaf_Curl_Virus    1971
# Tomato___healthy                          1926
# Tomato___Early_blight                     1920
# Tomato___Late_blight                      1851
# Tomato___Target_Spot                      1827
# Tomato___Tomato_mosaic_virus              1790
# Tomato___Bacterial_spot                   1702
# Name: count, dtype: int64

# %%
valid_images = []
valid_labels = []

for img, label in zip(x, y):
  if img.shape == (64, 64, 3):
    valid_images.append(img)
    valid_labels.append(label)

x = np.array(valid_images)
y = np.array(valid_labels)

print("Cleaned Data Shape: ", x.shape)
# Out:
# Cleaned Data Shape:  (12987, 64, 64, 3)

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

class_names = le.classes_
class_names
# Out:
# array(['Tomato___Bacterial_spot', 'Tomato___Early_blight',
#        'Tomato___Late_blight', 'Tomato___Target_Spot',
#        'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#        'Tomato___Tomato_mosaic_virus', 'Tomato___healthy'], dtype='<U38')

# %%
import random
import cv2
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in range(9):
  idx = random.randint(0, len(x)-1)
  plt.subplot(3, 3, i+1)
  plt.imshow(cv2.cvtColor(x[idx], cv2.COLOR_BGR2RGB))
  plt.title(class_names[y_encoded[idx]])
  plt.axis('off')
plt.tight_layout()
plt.show()

# %%
def extract_color_histogram(image, bins=(8, 8, 8)):

  image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
  hist = cv2.calcHist([image], [0, 1, 2], None, bins, [0, 256, 0, 256, 0, 256])
  hist = cv2.normalize(hist, hist).flatten()
  return hist

hist_features = [extract_color_histogram(img) for img in x]
x_features = np.array(hist_features)

# %%
x_features.shape
# Out:
# (12987, 512)

# %%
model = SVC(kernel='rbf', C=10, gamma='scale')

# %%
x_train, x_test, y_train, y_test = train_test_split(x_features, y_encoded, test_size=0.2, random_state=42)

model.fit(x_train, y_train)

y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)


f1 = f1_score(y_test, y_pred, average='weighted')
print("F1 Score", f1)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds',xticklabels=class_names)
plt.xlabel("predicted")
plt.ylabel("Actual")
plt.title("confusion Matrix")
plt.show()
# Out:
# Accuracy: 0.9665127020785219
# F1 Score 0.9664240391926339

# %%
from sklearn.metrics import classification_report

print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Classification Report:
#                                         precision    recall  f1-score   support
#
#                Tomato___Bacterial_spot       0.96      0.93      0.95       320
#                  Tomato___Early_blight       0.95      0.98      0.97       379
#                   Tomato___Late_blight       0.96      0.93      0.94       377
#                   Tomato___Target_Spot       0.95      0.98      0.97       368
# Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.97      0.96      0.96       407
#           Tomato___Tomato_mosaic_virus       0.99      1.00      1.00       340
#                       Tomato___healthy       0.99      0.98      0.99       407
#
#                               accuracy                           0.97      2598
#                              macro avg       0.97      0.97      0.97      2598
#                           weighted avg       0.97      0.97      0.97      2598
